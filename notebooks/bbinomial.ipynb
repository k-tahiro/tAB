# %%
from t_ab.bayesian.binomial import BinomialData, BinomialTest

# %%
a = BinomialData("A", 100, 30)
b = BinomialData("B", 10, 5)

# %%
btest = BinomialTest(a, b).sample()

# %%
btest.hist()

# %%
btest.probs
# Out:
# {'A': 0.09483, 'B': 0.90517}
